# %% [markdown]
# # Basic time series

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import numpy as np
import seaborn as sns
from pandas_datareader import data as pdr
import datetime as dt

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Out:
# /home/son/anaconda3/lib/python3.6/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# download 1 US stock
def download_one_stock(ticker='GOOG', start=dt.datetime(2019,1,1).date(),
                      end=dt.datetime(2020,1,1).date(),
                      cols=['Adj Close', 'Volume']):
    return pdr.get_data_yahoo(ticker, start, end)[cols]

# %%
df = download_one_stock()
df.head()
# Out:
#               Adj Close   Volume
# Date
# 2018-12-31  1035.609985  1493300
# 2019-01-02  1045.849976  1532600
# 2019-01-03  1016.059998  1841100
# 2019-01-04  1070.709961  2093900
# 2019-01-07  1068.390015  1981900

# %%
# Simple line plot
df['Adj Close'].plot()

# %%
df['Volume'].plot(style='k.')

# %%
# group prices with frequency 1 week
w_groups = df['Adj Close'].groupby(pd.Grouper(freq='1W'))
# maximum weekly prices
w_groups.max().plot()

# %%
# Grouped by month
m_groups = df['Adj Close'].groupby(pd.Grouper(freq='1M'))

# loop through months to plot
n = len(m_groups)
fig, axs = plt.subplots(4, figsize=(20,20))
iterator = iter(m_groups)
done_looping = False
count = 0
while not done_looping:
    try:
        month = next(iterator)
    except StopIteration:
        done_looping = True
    else:
        if count > 0 and count < 5:
            axs[count-1].set_title('Month {}'.format(month[0].month))
            axs[count-1].plot(month[1])
        count += 1

# %% [markdown]
# # Histogram, density plots

# %%
fig, axes = plt.subplots(1,2, figsize=(8,6))
df['Adj Close'].hist(ax=axes[0])
df['Adj Close'].plot(kind='kde', ax=axes[1])
axes[0].set_title('Histogram')
axes[1].set_title('Density Plot')
# Out:
# Text(0.5, 1.0, 'Density Plot')

# %%
# Grouped by month
m_groups = df['Adj Close'].groupby(pd.Grouper(freq='1M'))

# loop through months to plot
n = len(m_groups)

iterator = iter(m_groups)
done_looping = False
count = 0

months = dict()

while not done_looping:
    try:
        month = next(iterator)
    except StopIteration:
        done_looping = True
    else:
        if count > 0:
            colname = month[0].month
            months[colname] = month[1].values
        count += 1

# %%
figure(figsize=(8,6))
sns.boxplot(data=[months[k] for k in months.keys()])
plt.show()

# %% [markdown]
# # Autocorrelation and partial autocorrelation plots

# %%
fig, axes = plt.subplots(1,2, figsize=(12,6))
plot_acf(df['Adj Close'], ax=axes[0])
plot_pacf(df['Adj Close'], ax=axes[1])
plt.suptitle("Adj Close")
plt.show()

# %%
# Create new columns for Bollinger bands
df['20_day_mean'] = df['Adj Close'].rolling(window=20).mean()
    
# set .std(ddof=0) for population std instead of sample
df['20_day_std'] = df['Adj Close'].rolling(window=20).std() 

df['upper_band'] = df['20_day_mean'] + (df['20_day_std'] * 2)
df['lower_band'] = df['20_day_mean'] - (df['20_day_std'] * 2)

# %%
# Bollinger band
# set styles
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)

x_axis = df.index.get_level_values(0)

ax.fill_between(x_axis, df['upper_band'], df['lower_band'], 
               color='grey')

ax.plot(x_axis, df['Adj Close'], color='blue', lw=2)
ax.plot(x_axis, df['20_day_mean'], color='black', lw=2)

ax.set_title('20 day Bollinger band')

plt.show()
